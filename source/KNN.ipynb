# %%
#pip install Bio

# %%
from Bio import SeqIO
import numpy as np
import importlib
import fileDistanceProcessing as fdp
import importlib
importlib.reload(fdp)
# Out:
# <module 'fileDistanceProcessing' from '/home/bodo/Desktop/MATF/ip2_projekat/source/fileDistanceProcessing.py'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
import pandas as pd
def model_evaluation(y_test,y_pred,labels):
    print(f"Accuracy:  {accuracy_score(y_test, y_pred)}")
    
    cmtx = pd.DataFrame(
    confusion_matrix(y_test, y_pred, labels=labels ), 
    index=[ "true:"+s for s in labels ],
    columns=["pred:"+s for s in labels]
    )
    print("Confusion matrix:")
    print(cmtx)

# %%
X,y=fdp.read_dataset_virus()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, stratify=y)

# %% [markdown]
# <h1>KNN with simple difference distance (element-wise subtraction) </h1>

# %%
model = KNeighborsClassifier(n_neighbors=3, algorithm='ball_tree', metric=fdp.simple_difference_distance)

# %%
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='ball_tree',
#                      metric=<function simple_difference_distance at 0x7fa31df30040>,
#                      n_neighbors=3)

# %%
y_pred = model.predict(X_test)

# %%
model_evaluation(y_test,y_pred,['sars1','mers'])
# Out:
# Accuracy:  0.9965635738831615
# Confusion matrix:
#             pred:sars1  pred:mers
# true:sars1          37          0
# true:mers            8       2283

# %%
y_pred_train = model.predict(X_train)

# %%
model_evaluation(y_train, y_pred_train,['sars1','mers'])
# Out:
# Accuracy:  0.9980956411341515
# Confusion matrix:
#             pred:sars1  pred:mers
# true:sars1          74          0
# true:mers            9       4643

# %% [markdown]
# <h1>KNN with p-adic distance (p=2,5)  </h1>

# %%
model2 = KNeighborsClassifier(n_neighbors=3, algorithm='ball_tree', metric=fdp.five_two_adic_distance)

# %%
model2.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='ball_tree',
#                      metric=<function five_two_adic_distance at 0x7fa31df30160>,
#                      n_neighbors=3)

# %%
y_pred = model2.predict(X_test)

# %%
model_evaluation(y_test, y_pred, labels=['sars1', 'mers'])
# Out:
# Accuracy:  0.9982817869415808
# Confusion matrix:
#             pred:sars1  pred:mers
# true:sars1          35          2
# true:mers            2       2289

# %%
y_pred_train = model2.predict(X_train)

# %%
accuracy_score(y_train, y_pred_train)

# %%
confusion_matrix(y_train, y_pred_train)
